# %%
import langchain
import openai
import faiss
import chromadb
import pypdf
import tiktoken
import numpy as np
import pandas as pd

print(f"LangChain 版本: {langchain.__version__}")
print("🎉 核心依赖库全部导入成功！")
# Out:
# LangChain 版本: 1.2.15
# 🎉 核心依赖库全部导入成功！
